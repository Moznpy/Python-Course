# %%
# a boolean is a data type that represents one of two values: True or False.

# %%
type(True )

# %%
type(False)
# Out:
# bool

# %%
1 > 2
# Out:
# False

# %%
2 > 0
# Out:
# True

# %%
1 == 5
# Out:
# False

# %%
not True
# Out:
# False
